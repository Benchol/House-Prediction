# %%
import pandas as pd

# %%
dataFrame = pd.concat(
   map(pd.read_csv, ['Johannesburg0.csv', 'Johannesburg1.csv', 'Johannesburg2.csv', 'Johannesburg3.csv','Johannesburg4.csv', 'Johannesburg5.csv', 'Johannesburg6.csv', 'Johannesburg7.csv', 'Johannesburg8.csv', 'Johannesburg9.csv', 'Johannesburg10.csv', 'Johannesburg11.csv', 'Johannesburg12.csv', 'Johannesburg13.csv', 'Johannesburg14.csv', 'Johannesburg15.csv', 'Johannesburg16.csv', 'Johannesburg17.csv', 'Johannesburg18.csv', 'Johannesburg19.csv', 'Johannesburg20.csv', 'Johannesburg21.csv', 'Johannesburg22.csv']), ignore_index=True)

# %%
dataFrame
# Out:
#              price  bedrooms  bathrooms  parking space    Type of Property  \
# 0        R 665 000       2.0        1.0            1.0      Apartment/Flat
# 1        R 850 000       2.0        1.0            1.0      Apartment/Flat
# 2        R 689 000       2.0        1.0            1.0               House
# 3              POA       NaN        NaN            NaN  IndustrialProperty
# 4              POA       NaN        NaN            NaN  CommercialProperty
# ...            ...       ...        ...            ...                 ...
# 8060     R 900 000       NaN        NaN            NaN     VacantLand/Plot
# 8061   R 1 090 000       3.0        3.0            1.0               House
# 8062  R 34 999 000       NaN        NaN            NaN  CommercialProperty
# 8063  R 21 999 000       NaN        NaN            NaN  CommercialProperty
# 8064  R 11 500 000       NaN        NaN            NaN  CommercialProperty
#
#      Erf Size Floor Size Levies Rates and Taxes  Pets Allowed  Pool
# ...

# %%
dataFrame.to_csv('Johannesburg.csv', index=False, encoding='utf-8')
